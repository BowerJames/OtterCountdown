# %%
from dataclasses import dataclass, asdict

@dataclass
class Args:
    a: int = 5
    b: int = 10

def add(a: int, b: int) -> int:
    return a + b

# %%
args = Args()

add(**asdict(args))
# Out:
# 15
